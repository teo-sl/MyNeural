# %%
import numpy as np
ds = np.loadtxt('error.csv', delimiter=",")

# %%
import matplotlib.pyplot as plt
plt.plot(ds)
plt.show()

# %%
ds1 = np.loadtxt('error1.csv', delimiter=",")
plt.plot(ds1)
plt.show()

# %%
ds2 = np.loadtxt('error2.csv', delimiter=",")
plt.plot(ds2)
plt.show()

# %%
ds2 = np.loadtxt('error3.csv', delimiter=",")
plt.plot(ds2)
plt.show()

# %%
import matplotlib.pyplot as plt
ds = np.loadtxt('error.csv', delimiter=",")
plt.plot(ds)
plt.show()

# %%
import matplotlib.pyplot as plt
ds = np.loadtxt('error.csv', delimiter=",")
plt.plot(ds[0:100000])
plt.show()
